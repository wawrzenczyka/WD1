# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'..\data\preludium_with_additional_info.csv')
df
# Out:
#                        id       type  edition subpanel  budget  duration  \
# 0     2011/01/N/HS1/00761  PRELUDIUM        1      HS1   19500        12
# 1     2011/01/N/HS1/00856  PRELUDIUM        1      HS1   27794        12
# 2     2011/01/N/HS1/00960  PRELUDIUM        1      HS1   49100        30
# 3     2011/01/N/HS1/00985  PRELUDIUM        1      HS1   50025        30
# 4     2011/01/N/HS1/01942  PRELUDIUM        1      HS1    8375        12
# 5     2011/01/N/HS1/01952  PRELUDIUM        1      HS1   38027        12
# 6     2011/01/N/HS1/01959  PRELUDIUM        1      HS1   26500        24
# 7     2011/01/N/HS1/01979  PRELUDIUM        1      HS1  112245        22
# 8     2011/01/N/HS1/01987  PRELUDIUM        1      HS1   43125        36
# 9     2011/01/N/HS1/02667  PRELUDIUM        1      HS1   23000        24
# 10    2011/01/N/HS1/04410  PRELUDIUM        1      HS1   46400        24
# 11    2011/01/N/HS1/04432  PRELUDIUM        1      HS1   28600        24
# ...

# %%
panele=[
    "Fundamentalne pytania o naturę człowieka i otaczającej go rzeczywistości (HS1)",
    "Kultura i twórczość kulturowa (HS2)",
    "Wiedza o przeszłości (HS3)",
    "Jednostka, instytucje, rynki (HS4)",
    "Prawo, nauki o polityce, polityki publiczne (HS5)",
    "Człowiek i życie społeczne (HS6)",
    "Podstawowe procesy życiowe na poziomie molekularnym (NZ1)",
    "Genetyka, genomika (NZ2)",
    "Biologia na poziomie komórki (NZ3)",
    "Biologia na poziomie tkanek, narządów i organizmów (NZ4)",
    "Choroby niezakaźne ludzi i zwierząt (NZ5)",
    "Immunologia i choroby zakaźne ludzi i zwierząt (NZ6)",
    "Nauki o lekach i zdrowie publiczne (NZ7)",
    "Podstawy wiedzy o życiu na poziomie środowiskowym (NZ8)",
    "Podstawy stosowanych nauk o życiu (NZ9)",
    "Nauki matematyczne (ST1)",
    "Podstawowe składniki materii (ST2)",
    "Fizyka fazy skondensowanej (ST3)",
    "Chemia (ST4)",
    "Materiały (ST5)",
    "Informatyka i technologie informacyjne (ST6)",
    "Inżynieria systemów i telekomunikacji (ST7)",
    "Inżynieria procesów i produkcji (ST8)",
    "Astronomia i badania kosmiczne (ST9)",
    "Nauki o Ziemi (ST10)",

]
ho = ['HS'+str(i+1) for i in range(6)]
nz = ['NZ'+str(i+1) for i in range(9)]
st = ['ST'+str(i+1) for i in range(10)]
order =ho+nz+st

# %%
pdf = pd.read_csv(r'..\data\preludium_with_additional_info.csv')
pdf
# Out:
#                        id       type  edition subpanel  budget  duration  \
# 0     2011/01/N/HS1/00761  PRELUDIUM        1      HS1   19500        12
# 1     2011/01/N/HS1/00856  PRELUDIUM        1      HS1   27794        12
# 2     2011/01/N/HS1/00960  PRELUDIUM        1      HS1   49100        30
# 3     2011/01/N/HS1/00985  PRELUDIUM        1      HS1   50025        30
# 4     2011/01/N/HS1/01942  PRELUDIUM        1      HS1    8375        12
# 5     2011/01/N/HS1/01952  PRELUDIUM        1      HS1   38027        12
# 6     2011/01/N/HS1/01959  PRELUDIUM        1      HS1   26500        24
# 7     2011/01/N/HS1/01979  PRELUDIUM        1      HS1  112245        22
# 8     2011/01/N/HS1/01987  PRELUDIUM        1      HS1   43125        36
# 9     2011/01/N/HS1/02667  PRELUDIUM        1      HS1   23000        24
# 10    2011/01/N/HS1/04410  PRELUDIUM        1      HS1   46400        24
# 11    2011/01/N/HS1/04432  PRELUDIUM        1      HS1   28600        24
# ...

# %%
for i in range(len(order)):
    print(f'{order[i]}, {panele[i]}')
    pdf = pdf.replace(order[i], panele[i])
# Out:
# HS1, Fundamentalne pytania o naturę człowieka i otaczającej go rzeczywistości (HS1)
# HS2, Kultura i twórczość kulturowa (HS2)
# HS3, Wiedza o przeszłości (HS3)
# HS4, Jednostka, instytucje, rynki (HS4)
# HS5, Prawo, nauki o polityce, polityki publiczne (HS5)
# HS6, Człowiek i życie społeczne (HS6)
# NZ1, Podstawowe procesy życiowe na poziomie molekularnym (NZ1)
# NZ2, Genetyka, genomika (NZ2)
# NZ3, Biologia na poziomie komórki (NZ3)
# NZ4, Biologia na poziomie tkanek, narządów i organizmów (NZ4)
# NZ5, Choroby niezakaźne ludzi i zwierząt (NZ5)
# NZ6, Immunologia i choroby zakaźne ludzi i zwierząt (NZ6)
# NZ7, Nauki o lekach i zdrowie publiczne (NZ7)
# NZ8, Podstawy wiedzy o życiu na poziomie środowiskowym (NZ8)
# NZ9, Podstawy stosowanych nauk o życiu (NZ9)
# ST1, Nauki matematyczne (ST1)
# ST2, Podstawowe składniki materii (ST2)
# ST3, Fizyka fazy skondensowanej (ST3)
# ST4, Chemia (ST4)
# ST5, Materiały (ST5)
# ST6, Informatyka i technologie informacyjne (ST6)
# ...

# %%
pdf
# Out:
#                        id       type  edition  \
# 0     2011/01/N/HS1/00761  PRELUDIUM        1
# 1     2011/01/N/HS1/00856  PRELUDIUM        1
# 2     2011/01/N/HS1/00960  PRELUDIUM        1
# 3     2011/01/N/HS1/00985  PRELUDIUM        1
# 4     2011/01/N/HS1/01942  PRELUDIUM        1
# 5     2011/01/N/HS1/01952  PRELUDIUM        1
# 6     2011/01/N/HS1/01959  PRELUDIUM        1
# 7     2011/01/N/HS1/01979  PRELUDIUM        1
# 8     2011/01/N/HS1/01987  PRELUDIUM        1
# 9     2011/01/N/HS1/02667  PRELUDIUM        1
# 10    2011/01/N/HS1/04410  PRELUDIUM        1
# 11    2011/01/N/HS1/04432  PRELUDIUM        1
# 12    2011/01/N/HS1/04593  PRELUDIUM        1
# 13    2011/01/N/HS2/00510  PRELUDIUM        1
# 14    2011/01/N/HS2/00592  PRELUDIUM        1
# 15    2011/01/N/HS2/00704  PRELUDIUM        1
# 16    2011/01/N/HS2/00851  PRELUDIUM        1
# 17    2011/01/N/HS2/01062  PRELUDIUM        1
# 18    2011/01/N/HS2/01068  PRELUDIUM        1
# ...

# %%
plt.figure(figsize=(11,10))
hs = ["#E12647" for x  in range(6)]
nz = ["#798897" for x  in range(9)]
st = ["#E29897" for x  in range(10)]
allcls = hs+nz+st
ho = ['HS'+str(i+1) for i in range(6)]
nz = ['NZ'+str(i+1) for i in range(9)]
st = ['ST'+str(i+1) for i in range(10)]
res_pdf=pdf.copy()
res_pdf['budget'] = pdf['budget']/1000
order =ho+nz+st 
sns.barplot(x='budget', y='subpanel',data=res_pdf, palette=allcls, order=panele )
plt.xlabel('Średni budżet (tys. zł)',fontsize=18)
plt.ylabel('',fontsize=18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
ax = plt.gca()
sns.despine(top=True, right=True, left=True, bottom=True)
#plt.title("Średni budżet na panel", fontdict=None, loc='center', pad=None)
plt.savefig('bar_panels_budgets.png', format='png', bbox_inches='tight',transparent=True)
#25
# Out:
# C:\Users\ulano\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
panel_df = df.copy()
panel_df["subpanel"] =panel_df["subpanel"].str.replace('\d+', '')
panel_df
# Out:
#                        id       type  edition subpanel  budget  duration  \
# 0     2011/01/N/HS1/00761  PRELUDIUM        1       HS   19500        12
# 1     2011/01/N/HS1/00856  PRELUDIUM        1       HS   27794        12
# 2     2011/01/N/HS1/00960  PRELUDIUM        1       HS   49100        30
# 3     2011/01/N/HS1/00985  PRELUDIUM        1       HS   50025        30
# 4     2011/01/N/HS1/01942  PRELUDIUM        1       HS    8375        12
# 5     2011/01/N/HS1/01952  PRELUDIUM        1       HS   38027        12
# 6     2011/01/N/HS1/01959  PRELUDIUM        1       HS   26500        24
# 7     2011/01/N/HS1/01979  PRELUDIUM        1       HS  112245        22
# 8     2011/01/N/HS1/01987  PRELUDIUM        1       HS   43125        36
# 9     2011/01/N/HS1/02667  PRELUDIUM        1       HS   23000        24
# 10    2011/01/N/HS1/04410  PRELUDIUM        1       HS   46400        24
# 11    2011/01/N/HS1/04432  PRELUDIUM        1       HS   28600        24
# ...

# %%
plt.figure(figsize=(7,8))
sns.barplot(x='subpanel', y='budget',data=panel_df )
# Out:
# C:\Users\ulano\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
panel_with_budget = panel_df.groupby(['subpanel'])['budget'].sum().reset_index(name='budget')
panel_with_budget
# Out:
#   subpanel     budget
# 0       HS  121035343
# 1       NZ  248486128
# 2       ST  239803779

# %%
hs_budget=panel_with_budget[panel_with_budget.subpanel == 'HS'].budget.values[0]
nz_budget=panel_with_budget[panel_with_budget.subpanel == 'NZ'].budget.values[0]
st_budget=panel_with_budget[panel_with_budget.subpanel == 'ST'].budget.values[0]
sum_budget = hs_budget+nz_budget+st_budget
hs_budget+nz_budget+st_budget
# Out:
# 609325250

# %%
# Pie chart
labels = ['Nauki Humanistyczne - HS', 'Nauki o Życiu - NZ', 'Nauki Ścisłe i Techniczne - ST']
sizes = [hs_budget/sum_budget*100, nz_budget/sum_budget*100, st_budget/sum_budget*100]
explode = (0, 0.05, 0)  
fig1, ax1 = plt.subplots()
#plt.figure(figsize=(5.80, 4.00), dpi=100)
_, _, autotexts=ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90,colors=['#E12647','#E29897','#798897'],textprops={'fontsize': 14})
# for autotext in autotexts:
#     autotext.set_color('white')
plt.setp(autotexts, **{'color':'white', 'weight':'bold', 'fontsize':17})
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.tight_layout()
#plt.title("Procent pieniędzy jaki przeznaczono przez wszystkie lata \n na poszczególne kategorie", fontdict=None, loc='center', pad=None)
plt.savefig('pie_panels_budgets.png', format='png', bbox_inches='tight',transparent=True)

# %%
desc = pd.read_csv(r'..\data\preludium_descriptors.csv')
desc_df = df.merge(desc, left_on = 'id', right_on = 'Id')
desc_df
# Out:
#                         id       type  edition subpanel  budget  duration  \
# 0      2011/01/N/HS1/00761  PRELUDIUM        1      HS1   19500        12
# 1      2011/01/N/HS1/00761  PRELUDIUM        1      HS1   19500        12
# 2      2011/01/N/HS1/00761  PRELUDIUM        1      HS1   19500        12
# 3      2011/01/N/HS1/00856  PRELUDIUM        1      HS1   27794        12
# 4      2011/01/N/HS1/00960  PRELUDIUM        1      HS1   49100        30
# 5      2011/01/N/HS1/00985  PRELUDIUM        1      HS1   50025        30
# 6      2011/01/N/HS1/01942  PRELUDIUM        1      HS1    8375        12
# 7      2011/01/N/HS1/01942  PRELUDIUM        1      HS1    8375        12
# 8      2011/01/N/HS1/01942  PRELUDIUM        1      HS1    8375        12
# 9      2011/01/N/HS1/01952  PRELUDIUM        1      HS1   38027        12
# 10     2011/01/N/HS1/01952  PRELUDIUM        1      HS1   38027        12
# 11     2011/01/N/HS1/01959  PRELUDIUM        1      HS1   26500        24
# ...

# %%
mean = desc_df.groupby(['Descriptors']).agg({'budget':['mean','std']})
mean.columns = ['mean','std']
mean.reindex(columns=sorted(mean.columns))
mean = mean.sort_values(by=['mean'], ascending=False)
mean = mean.head(10)
mean = mean.reset_index()
data = desc_df[desc_df['Descriptors'].isin(mean['Descriptors'])]
data = data.sort_values(by=['budget'], ascending=False)

# %%
plt.figure(figsize=(10,5))

sns.barplot(x='Descriptors', y='mean',data=mean )
plt.xlabel('Subpanel')
plt.ylabel('Średni budżet')
plt.title("Średni budżet na subpanel", fontdict=None, loc='center', pad=None)
plt.savefig('subpanels_budgets.svg', format='svg', bbox_inches='tight')
